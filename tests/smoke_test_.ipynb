# %%
import sys
from pathlib import Path

# Force notebook to recognize project root
import os
ROOT = Path(os.getcwd()).resolve().parents[0] # one level up from tests/
if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))

import pandas as pd
from src.inference_pipeline.inference import predict

# Load a few rows of already preprocessed data
sample_path = ROOT / "data/processed/cleaning_eval.csv"
df = pd.read_csv(sample_path).sample(5, random_state=42).reset_index(drop=True)

print("Input sample:")
display(df.head())

# Run inference
preds_df = predict(df)
print("✅ Predictions returned")
display(preds_df[["predicted_price"]].head())
# Out:
# 📂 Inference using project root: F:\AI Projects\Regression Project
# Input sample:
#          date  median_sale_price  median_list_price  median_ppsf  \
# 0  2020-08-31           660000.0           712000.0   765.661253
# 1  2020-04-30           230500.0           247000.0   137.775187
# 2  2021-07-31           907500.0           965000.0   715.753425
# 3  2020-11-30           155000.0           159950.0   106.400050
# 4  2020-11-30           235000.0           225000.0   141.505971
#
#    median_list_ppsf  homes_sold  pending_sales  new_listings  inventory  \
# 0        762.180974        21.0           23.0          30.0       14.0
# 1        155.511111        28.0           39.0          33.0       29.0
# 2        713.867093        93.0           80.0          99.0       34.0
# 3        103.896104        39.0           40.0          38.0       22.0
# 4        148.678905       159.0          203.0         214.0      140.0
#
#    median_dom  ...  Median Home Value  Total Labor Force  \
# 0        40.0  ...           725600.0             9897.0
# 1        34.5  ...           213800.0             8003.0
# 2         8.0  ...           627800.0            31820.0
# 3        22.0  ...           118300.0             8432.0
# 4        22.5  ...           162300.0            23924.0
#
#    Unemployed Population Total School Age Population  Total School Enrollment  \
# 0                  618.0                     15542.0                  15542.0
# 1                  531.0                     14607.0                  14607.0
# 2                 1575.0                     44018.0                  44018.0
# 3                  813.0                     15883.0                  15883.0
# 4                 1366.0                     45511.0                  45511.0
#
#    Median Commute Time          price      city_key      lat       lng
# 0               8452.0  720570.902347           san  35.3871 -120.4044
# 1               7113.0  214749.630194  philadelphia  39.9056  -75.3020
# 2              26378.0  836406.492429           san  36.9095 -121.3759
# 3               7205.0  135253.800938       chicago  41.6675  -87.9597
# 4              21470.0  205928.312432       orlando  28.4343  -81.3630
#
# [5 rows x 41 columns]
# ⚠️ Skipping city merge: no 'city_full' column present.
# ✅ Dropped 0 duplicate rows (excluding date/year).
# ✅ Removed 0 rows with median_list_price > 19M.
# ✅ Predictions returned
#    predicted_price
# 0     1.088110e+06
# 1     3.010199e+05
# 2     1.037936e+06
# 3     2.343687e+05
# 4     2.899042e+05
